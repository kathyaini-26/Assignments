# %%
dir(dict)
# Out:
# ['__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__ior__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__ne__',
#  '__new__',
#  '__or__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__ror__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'clear',
#  'copy',
#  'fromkeys',
#  'get',
#  'items',
#  'keys',
#  'pop',
#  'popitem',
#  'setdefault',
#  'update',
#  'values']

# %% [markdown]
# #### Creating dictionary objects

# %%
s1 = {
    'Name':'Thomas',
    'Age':25,
    'Course':'Analytics'
}

# %%
s1
# Out:
# {'Name': 'Thomas', 'Age': 25, 'Course': 'Analytics'}

# %%
type(s1)
# Out:
# dict

# %%
e1 = dict(name='Thomas',job='Manager',salary=1200)
e1
# Out:
# {'name': 'Thomas', 'job': 'Manager', 'salary': 1200}

# %%
type(e1)
# Out:
# dict

# %%
marks = {
    'Tom': [67,89,95],
    'Tim':[98,97,90],
    'Jon':[23,43,56]
}

# %%
marks
# Out:
# {'Tom': [67, 89, 95], 'Tim': [98, 97, 90], 'Jon': [23, 43, 56]}

# %%
marks2 = dict(Tom=[88,99,70], Jon=[34,56,67])
marks2
# Out:
# {'Tom': [88, 99, 70], 'Jon': [34, 56, 67]}

# %%
d1 = {
    1 : 'One',
    12.5:'Fraction',
    'Name':'Janet',
    (0,0) : 'Origin',
    #[1,2] :'NA'
}

# %%
d1
# Out:
# {1: 'One', 12.5: 'Fraction', 'Name': 'Janet', (0, 0): 'Origin'}

# %%
d2 = dict.fromkeys(['Tom','Jon','Jim','Tim'])
d2
# Out:
# {'Tom': None, 'Jon': None, 'Jim': None, 'Tim': None}

# %%
d3 = dict.fromkeys(['Tom','Jon','Jim','Tim'],0)
d3
# Out:
# {'Tom': 0, 'Jon': 0, 'Jim': 0, 'Tim': 0}

# %%
names = ('Tom','Tim','Jon','Jim','Jon','Kim')
marks = [67,87,97,90,34,56]

# %%
zip(names,marks)

# %%
for x in zip(names,marks):
    print(x)
# Out:
# ('Tom', 67)
# ('Tim', 87)
# ('Jon', 97)
# ('Jim', 90)
# ('Jon', 34)
# ('Kim', 56)

# %%
d3 = dict(zip(names,marks))
d3
# Out:
# {'Tom': 67, 'Tim': 87, 'Jon': 34, 'Jim': 90, 'Kim': 56}

# %%
states = ['TN','AP','UP','MP', 'Kerala']
capitals = ['Chennai','Amaravathy','Lucknow','Bhopal','Trivandrum']

# %%
dstates = dict(zip(states,capitals))
dstates
# Out:
# {'TN': 'Chennai',
#  'AP': 'Amaravathy',
#  'UP': 'Lucknow',
#  'MP': 'Bhopal',
#  'Kerala': 'Trivandrum'}

# %% [markdown]
# #### Access Values from dictionary

# %%
dstates['UP']
# Out:
# 'Lucknow'

# %%
dstates['AP']
# Out:
# 'Amaravathy'

# %%
dstates['Telangana']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 dstates['Telangana']
#
# KeyError: 'Telangana'

# %%
dstates.get('Telangana')

# %%
dstates.get('TN')
# Out:
# 'Chennai'

# %%
dstates.keys()
# Out:
# dict_keys(['TN', 'AP', 'UP', 'MP', 'Kerala'])

# %%
dstates.values()
# Out:
# dict_values(['Chennai', 'Amaravathy', 'Lucknow', 'Bhopal', 'Trivandrum'])

# %%
dstates.items()
# Out:
# dict_items([('TN', 'Chennai'), ('AP', 'Amaravathy'), ('UP', 'Lucknow'), ('MP', 'Bhopal'), ('Kerala', 'Trivandrum')])

# %% [markdown]
# #### Add/Update values in the dictionary

# %%
dstates
# Out:
# {'TN': 'Chennai',
#  'AP': 'Amaravathy',
#  'UP': 'Lucknow',
#  'MP': 'Bhopal',
#  'Kerala': 'Trivandrum'}

# %%
dstates['Karnataka'] = 'Bengaluru'

# %%
dstates
# Out:
# {'TN': 'Chennai',
#  'AP': 'Amaravathy',
#  'UP': 'Lucknow',
#  'MP': 'Bhopal',
#  'Kerala': 'Trivandrum',
#  'Karnataka': 'Bengaluru'}

# %%
dstates['Kerala'] = 'Kochi'

# %%
dstates
# Out:
# {'TN': 'Chennai',
#  'AP': 'Amaravathy',
#  'UP': 'Lucknow',
#  'MP': 'Bhopal',
#  'Kerala': 'Kochi',
#  'Karnataka': 'Bengaluru'}

# %%
dstates.setdefault('AP', 'Vizag')
# Out:
# 'Amaravathy'

# %%
dstates.setdefault('Telangana','Hyderabad')
# Out:
# 'Hyderabad'

# %%
dstates
# Out:
# {'TN': 'Chennai',
#  'AP': 'Amaravathy',
#  'UP': 'Lucknow',
#  'MP': 'Bhopal',
#  'Kerala': 'Kochi',
#  'Karnataka': 'Bengaluru',
#  'Telangana': 'Hyderabad'}

# %%
d1 = {
    1:'Mango',
    2: 'Guava',
    3:'Papaya'
}

# %%
d2 = {
    2:'Strawberry',
    3: 'Orange',
    4: 'Grapes'
}

# %%
d1.update(d2)

# %%
d1
# Out:
# {1: 'Mango', 2: 'Strawberry', 3: 'Orange', 4: 'Grapes'}

# %%
d2
# Out:
# {2: 'Strawberry', 3: 'Orange', 4: 'Grapes'}

# %% [markdown]
# #### Remove elements from a dictionary

# %%
s1
# Out:
# {'Name': 'Thomas', 'Age': 25, 'Course': 'Analytics'}

# %%
s1.pop('Age')
# Out:
# 25

# %%
s1
# Out:
# {'Name': 'Thomas', 'Course': 'Analytics'}

# %%
s1.popitem()
# Out:
# ('Course', 'Analytics')

# %%
s1.clear()

# %%
s1
# Out:
# {}
