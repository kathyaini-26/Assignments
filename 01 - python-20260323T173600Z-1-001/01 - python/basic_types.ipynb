# %% [markdown]
# #### Jupyter Shortcuts
#
# + esc + a - Add a cell above the current cell
# + esc + b - Add a cell below the current cell
# + esc + m - Convert current cell to markdown cell
# + esc + y - Convert current cell to code cell
# + esc + x - Delete current cell

# %%
# This is a comment
print('hello')
# Out:
# hello

# %% [markdown]
# #### Data Types

# %%
# Integer
x = 10
print(x)
type(x)
# Out:
# 10
# int

# %%
print(x)
# Out:
# 10

# %%
# Float
x = 10.6
print(x)
type(x)
# Out:
# 10.6
# float

# %%
# Boolean
a = True
print(a)
type(a)
# Out:
# True
# bool

# %% [markdown]
# #### Arithmetic Operations

# %%
x = 10
y = 3

# %%
# Addition
x + y
# Out:
# 13

# %%
# Subtraction 
x - y
# Out:
# 7

# %%
# Multiplication 
x * y
# Out:
# 30

# %%
# Division 
x / y
# Out:
# 3.3333333333333335

# %%
# Module division
x % 3
# Out:
# 1

# %%
# Flore Division 
x // y
# Out:
# 3

# %%
# Power
x ** 3
# Out:
# 1000

# %% [markdown]
# ### Logical Operations

# %%
a = True
b = False

# %%
a and b
# Out:
# False

# %%
a or b
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# True

# %% [markdown]
# ## Sequence Types

# %%
# List
lst = [78,90,45,63,55,97,67,21,45]
lst
# Out:
# [78, 90, 45, 63, 55, 97, 67, 21, 45]

# %%
type(lst)
# Out:
# list

# %%
mixed_lst = [10, 6.78, True, [23,45,67], (1,2,3),'Apple']
mixed_lst
# Out:
# [10, 6.78, True, [23, 45, 67], (1, 2, 3), 'Apple']

# %%
shop_lst = ['Apple','Soap','Shampoo','Rice','Notebook']
shop_lst
# Out:
# ['Apple', 'Soap', 'Shampoo', 'Rice', 'Notebook']

# %%
# Tuple
t1 = (78,90,45,63,55,97,67,21,45)
t1
# Out:
# (78, 90, 45, 63, 55, 97, 67, 21, 45)

# %%
type(t1)
# Out:
# tuple

# %%
t2 = (10, 6.78, True, [23,45,67], (1,2,3),'Apple')
t2
# Out:
# (10, 6.78, True, [23, 45, 67], (1, 2, 3), 'Apple')

# %%
# String
s1 = 'Python 3.0'
s1
# Out:
# 'Python 3.0'

# %%
type(s1)
# Out:
# str

# %%
s2 = "Hello World"
s2
# Out:
# 'Hello World'

# %%
type(s2)
# Out:
# str

# %%
# Multiline 
s3 =  '''Hello World!
How are you today'''
print(s3)
# Out:
# Hello World!
# How are you today

# %%
s3
# Out:
# 'Hello World!\nHow are you today'

# %% [markdown]
# #### 1. Positional Indexing - Accessing Elements Using Index

# %%
lst[2]
# Out:
# 45

# %%
t1[0]
# Out:
# 78

# %%
s1[8]
# Out:
# '.'

# %%
mixed_lst
# Out:
# [10, 6.78, True, [23, 45, 67], (1, 2, 3), 'Apple']

# %%
mixed_lst[3]
# Out:
# [23, 45, 67]

# %%
mixed_lst[3][2]
# Out:
# 67

# %%
mixed_lst[-1][-2]
# Out:
# 'l'

# %% [markdown]
# ##### Negative Index - Counting from the end

# %%
s1[-2]
# Out:
# '.'

# %%
lst[-1]
# Out:
# 45

# %%
s3[-1]
# Out:
# 'y'

# %% [markdown]
# #### Slicing a Sequence

# %%
lst
# Out:
# [78, 90, 45, 63, 55, 97, 67, 21, 45]

# %%
lst[3:7]
# Out:
# [63, 55, 97, 67]

# %%
lst[:6]
# Out:
# [78, 90, 45, 63, 55, 97]

# %%
lst[5:]
# Out:
# [97, 67, 21, 45]

# %%
s2
# Out:
# 'Hello World'

# %%
s2[6:]
# Out:
# 'World'

# %%
s2[-5:]
# Out:
# 'World'

# %% [markdown]
# #### Iterating Over a sequence

# %%
shop_lst
# Out:
# ['Apple', 'Soap', 'Shampoo', 'Rice', 'Notebook']

# %%
for x in shop_lst:
    print(x)
    print('hi')
print('____________')
# Out:
# Apple
# hi
# Soap
# hi
# Shampoo
# hi
# Rice
# hi
# Notebook
# hi
# ____________

# %%
mixed_lst
# Out:
# [10, 6.78, True, [23, 45, 67], (1, 2, 3), 'Apple']

# %%
for x in mixed_lst:
    print(x, ' -> ', type(x))
print('Done')
# Out:
# 10  ->  <class 'int'>
# 6.78  ->  <class 'float'>
# True  ->  <class 'bool'>
# [23, 45, 67]  ->  <class 'list'>
# (1, 2, 3)  ->  <class 'tuple'>
# Apple  ->  <class 'str'>
# Done

# %%
for x in 'Python3.0':
    print(x, ' -> ', type(x))
# Out:
# P  ->  <class 'str'>
# y  ->  <class 'str'>
# t  ->  <class 'str'>
# h  ->  <class 'str'>
# o  ->  <class 'str'>
# n  ->  <class 'str'>
# 3  ->  <class 'str'>
# .  ->  <class 'str'>
# 0  ->  <class 'str'>

# %% [markdown]
# #### Common Functions

# %%
len(lst)
# Out:
# 9

# %%
len(s3)
# Out:
# 30

# %%
min(lst)
# Out:
# 21

# %%
max(lst)
# Out:
# 97

# %%
sum(lst)
# Out:
# 561

# %%
sum(lst) / len(lst)
# Out:
# 62.333333333333336

# %%
#### Membership Function
'Sugar' in shop_lst
# Out:
# False

# %%
'Soap' in shop_lst
# Out:
# True

# %%
'e' in s2
# Out:
# True

# %%
'#' in s2
# Out:
# False

# %% [markdown]
# #### '+' operator

# %%
l1 = [1,2,3]
l2 = [4,5,6]

# %%
l1 + l2
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
'Hello ' + 'World'
# Out:
# 'Hello World'

# %% [markdown]
# #### '*' operator

# %%
l1
# Out:
# [1, 2, 3]

# %%
l1 * 3
# Out:
# [1, 2, 3, 1, 2, 3, 1, 2, 3]

# %%
'Hello '*3
# Out:
# 'Hello Hello Hello '

# %%
print('_'*30)
# Out:
# ______________________________

# %% [markdown]
# ### List

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %% [markdown]
# #### Adding elements to a list

# %%
lst
# Out:
# [78, 90, 45, 63, 55, 97, 67, 21, 45]

# %% [markdown]
# ##### Add one element at the end of the list

# %%
lst.append(100)

# %%
lst
# Out:
# [78, 90, 45, 63, 55, 97, 67, 21, 45, 100]

# %%
shop_lst.append('Sugar')
shop_lst
# Out:
# ['Apple', 'Soap', 'Shampoo', 'Rice', 'Notebook', 'Sugar']

# %% [markdown]
# ##### Add multiple elements at the end of the list

# %%
lst.extend([1,2,3])
lst
# Out:
# [78, 90, 45, 63, 55, 97, 67, 21, 45, 100, 1, 2, 3]

# %%
lst.append([1,2,3])

# %%
lst
# Out:
# [78, 90, 45, 63, 55, 97, 67, 21, 45, 100, 1, 2, 3, [1, 2, 3]]

# %%
additional_elems  = ['Notebook','Paper','Jam']
shop_lst.extend(additional_elems)
shop_lst
# Out:
# ['Apple',
#  'Soap',
#  'Shampoo',
#  'Rice',
#  'Notebook',
#  'Sugar',
#  'Notebook',
#  'Paper',
#  'Jam']

# %%
lst.insert(3,33)
lst
# Out:
# [78, 90, 45, 33, 63, 55, 97, 67, 21, 45, 100, 1, 2, 3, [1, 2, 3]]

# %% [markdown]
# #### Remove elements from a list

# %%
lst.pop()
# Out:
# [1, 2, 3]

# %%
lst
# Out:
# [78, 90, 45, 33, 63, 55, 97, 67, 21, 45, 100, 1, 2, 3]

# %%
lst.pop()
# Out:
# 3

# %%
lst
# Out:
# [78, 90, 45, 33, 63, 55, 97, 67, 21, 45, 100, 1, 2]

# %%
# Remove element at position 3
lst.pop(3)
# Out:
# 33

# %%
# Remove first occurance of 97
lst.remove(97)

# %%
lst
# Out:
# [78, 90, 45, 63, 55, 67, 21, 45, 100, 1, 2]

# %%
shop_lst
# Out:
# ['Apple',
#  'Soap',
#  'Shampoo',
#  'Rice',
#  'Notebook',
#  'Sugar',
#  'Notebook',
#  'Paper',
#  'Jam']

# %%
l1 = [8,7,6]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %% [markdown]
# #### Order the elements of a list

# %%
lst
# Out:
# [78, 90, 45, 63, 55, 67, 21, 45, 100, 1, 2]

# %%
# Ascending Order
lst.sort()

# %%
lst
# Out:
# [1, 2, 21, 45, 45, 55, 63, 67, 78, 90, 100]

# %%
print(lst.sort())
# Out:
# None

# %%
lst =[78, 90, 45, 63, 55, 67, 21, 45, 100, 1, 2]

# %%
# Descending Order
lst.sort(reverse=True)

# %%
lst
# Out:
# [100, 90, 78, 67, 63, 55, 45, 45, 21, 2, 1]

# %%
shop_lst
# Out:
# ['Apple',
#  'Soap',
#  'Shampoo',
#  'Rice',
#  'Notebook',
#  'Sugar',
#  'Notebook',
#  'Paper',
#  'Jam']

# %%
shop_lst.sort()
shop_lst
# Out:
# ['Apple',
#  'Jam',
#  'Notebook',
#  'Notebook',
#  'Paper',
#  'Rice',
#  'Shampoo',
#  'Soap',
#  'Sugar']

# %%
mixed_lst
# Out:
# [10, 6.78, True, [23, 45, 67], (1, 2, 3), 'Apple']

# %%
# Cannot order list of mixed datatypes
#mixed_lst.sort()

# %%
l1 = [45,67,23]

# %%
# Reverse without ordering
l1.reverse()

# %%
l1
# Out:
# [23, 67, 45]

# %% [markdown]
# #### Count the number of occurances of an element

# %%
name_lst = ['Tom','Tim','Jon','Jim','Jon','Kim']

# %%
name_lst.count('Jon')
# Out:
# 2

# %%
name_lst.count('Tim')
# Out:
# 1

# %%
l2 = [1,2,1,3,4,1,6,7]

# %%
l2.count(1)
# Out:
# 3

# %%
l2.count(2)
# Out:
# 1

# %% [markdown]
# #### Index position of the first occurance of an element

# %%
name_lst.index('Jim')
# Out:
# 3

# %%
name_lst.index('Jon')
# Out:
# 2

# %% [markdown]
# #### Assignment Vs Copy

# %% [markdown]
# ###### Assignment

# %%
l1 = [1,2,3]
l2 = l1

# %%
l1
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [1, 2, 3]

# %%
l2.append(100)

# %%
l2
# Out:
# [1, 2, 3, 100]

# %%
l1
# Out:
# [1, 2, 3, 100]

# %% [markdown]
# ###### copy()

# %%
l1 = [1,2,3]
l2 = l1.copy()

# %%
l1
# Out:
# [1, 2, 3]

# %%
l2
# Out:
# [1, 2, 3]

# %%
l2.append(100)

# %%
l2
# Out:
# [1, 2, 3, 100]

# %%
l1
# Out:
# [1, 2, 3]

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
names = ('Tom','Tim','Jon','Jim','Jon','Kim')
names
# Out:
# ('Tom', 'Tim', 'Jon', 'Jim', 'Jon', 'Kim')

# %%
type(names)
# Out:
# tuple

# %%
names.count('Jon')
# Out:
# 2

# %%
names.index('Jon')
# Out:
# 2

# %%
#names.append()

# %% [markdown]
# #### String

# %%
dir(str)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
# ...

# %%
s1 = 'hello world'

# %%
s1.capitalize()
# Out:
# 'Hello world'

# %%
s1.title()
# Out:
# 'Hello World'

# %%
s1.upper()
# Out:
# 'HELLO WORLD'

# %%
s1
# Out:
# 'hello world'

# %%
l1.sort()

# %%
upp_s1 = s1.upper()
upp_s1
# Out:
# 'HELLO WORLD'

# %%
s1
# Out:
# 'hello world'

# %%
s2 = 'I Love Python'

# %%
s2.lower()
# Out:
# 'i love python'

# %%
s2.swapcase()
# Out:
# 'i lOVE pYTHON'

# %%
s3 = '   python  '

# %%
s3.lstrip(), s3.rstrip(), s3.strip()
# Out:
# ('python  ', '   python', 'python')

# %%
s4 = 'This is a big sentence for testing split function'

# %%
s4.split()
# Out:
# ['This', 'is', 'a', 'big', 'sentence', 'for', 'testing', 'split', 'function']

# %%
s5 = 'Apple,Grapes,Lemon,Melon,Mango'

# %%
s5.split(',')
# Out:
# ['Apple', 'Grapes', 'Lemon', 'Melon', 'Mango']

# %%
s5 = 'Apple|Grapes,Lemon|Melon|Mango'
s5.split('|')
# Out:
# ['Apple', 'Grapes,Lemon', 'Melon', 'Mango']

# %%
fruit_lst = ['Apple', 'Grapes', 'Lemon', 'Melon', 'Mango']
fruit_lst
# Out:
# ['Apple', 'Grapes', 'Lemon', 'Melon', 'Mango']

# %%
' '.join(fruit_lst)
# Out:
# 'Apple Grapes Lemon Melon Mango'

# %%
','.join(fruit_lst)
# Out:
# 'Apple,Grapes,Lemon,Melon,Mango'

# %%
s6 = 'Anarkali'

# %%
s6.replace('Anar','Champa')
# Out:
# 'Champakali'
